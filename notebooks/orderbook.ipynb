# %%
from pybl3p.public import orderbook
import pandas as pd
# %matplotlib inline

# %%
asks, bids = orderbook()

# %%
asks.plot(logy=True);
# Out:
# /home/gijs/Work/bl3p/venv/lib/python3.7/site-packages/matplotlib/mathtext.py:2542: SyntaxWarning: Exception creating Regex for oneOf, building MatchFirst
#   p.subsuperop    <<= oneOf(["_", "^"])

# %%
bids.plot(logy=True);
